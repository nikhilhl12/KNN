# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
dt = pd.read_csv("Zoo.csv")
dt
# Out:
#     animal name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# 0          1         1         1         0     0     4     0         0
# 1          1         1         1         0     0     4     1         0
# 2          1         1         0         0     1     0     1         0
# 3          1         1         1         0     0     4     0         0
# 4          1         1         1         0     0     4     1         0
# ..       ...       ...       ...       ...   ...   ...   ...       ...
# 96         1         1         1         0     0     2     1         0
# 97         0         0         1         1     0     6     0         0
# 98         1         1         1         0     0     4     1         0
# 99         0         0         1         0     0     0     0         0
# 100        0         1         1         0     0     2     1         0
#
#      catsize  type
# 0          1     1
# 1          1     1
# 2          0     4
# 3          1     1
# 4          1     1
# ..       ...   ...
# 96         1     1
# 97         0     6
# 98         1     1
# 99         0     7
# 100        0     2
#
# [101 rows x 18 columns]

# %%
dt.duplicated().sum()
# Out:
# 0

# %%
array = dt.values
x = array[:,1:-1]
y= array[:,-1]
y= y.astype('int')
y
# Out:
# array([1, 1, 4, 1, 1, 1, 1, 4, 4, 1, 1, 2, 4, 7, 7, 7, 2, 1, 4, 1, 2, 2,
#        1, 2, 6, 5, 5, 1, 1, 1, 6, 1, 1, 2, 4, 1, 1, 2, 4, 6, 6, 2, 6, 2,
#        1, 1, 7, 1, 1, 1, 1, 6, 5, 7, 1, 1, 2, 2, 2, 2, 4, 4, 3, 1, 1, 1,
#        1, 1, 1, 1, 1, 2, 7, 4, 1, 1, 3, 7, 2, 2, 3, 7, 4, 2, 1, 7, 4, 2,
#        6, 5, 3, 3, 4, 1, 1, 2, 1, 6, 1, 7, 2])

# %%
dt["type"].value_counts()
# Out:
# 1    41
# 2    20
# 4    13
# 7    10
# 6     8
# 3     5
# 5     4
# Name: type, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.4,shuffle=True,random_state=20)

# %%
model= KNeighborsClassifier(n_neighbors=6)
model.fit(x_train,y_train)
pred= model.predict(x_test)
accuracy_score(pred,y_test)
# Out:
# 0.8536585365853658

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.91      0.95        22
#            2       1.00      1.00      1.00         5
#            3       0.00      0.00      0.00         1
#            4       0.67      1.00      0.80         6
#            5       0.00      0.00      0.00         2
#            6       0.75      1.00      0.86         3
#            7       1.00      0.50      0.67         2
#
#     accuracy                           0.85        41
#    macro avg       0.63      0.63      0.61        41
# weighted avg       0.86      0.85      0.85        41

# %% [markdown]
# # visualizing the cv

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
k_range = [2*i+1 for i in range(0,20)]
k_scores = []
for k in k_range:
    knn= KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn,x_train , y_train,cv = 10)
    k_scores.append(scores.mean())
    print("k value = ",k)
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(x_train,y_train)
    pred = model.predict(x_test)
    print(classification_report(y_test,pred))
# Out:
# k value =  1
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00         5
#            3       0.00      0.00      0.00         1
#            4       0.86      1.00      0.92         6
#            5       1.00      0.50      0.67         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.95        41
#    macro avg       0.84      0.79      0.80        41
# weighted avg       0.95      0.95      0.95        41
#
# k value =  3
#               precision    recall  f1-score   support
#
#            1       1.00      0.91      0.95        22
#            2       1.00      1.00      1.00         5
#            3       0.00      0.00      0.00         1
#            4       0.67      1.00      0.80         6
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.93        41
#    macro avg       0.81      0.84      0.82        41
# weighted avg       0.93      0.93      0.92        41
#
# k value =  5
#               precision    recall  f1-score   support
#
#            1       1.00      0.91      0.95        22
#            2       1.00      1.00      1.00         5
#            3       0.00      0.00      0.00         1
#            4       0.67      1.00      0.80         6
#            5       1.00      0.50      0.67         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.90        41
#    macro avg       0.81      0.77      0.77        41
# weighted avg       0.93      0.90      0.90        41
#
# k value =  7
#               precision    recall  f1-score   support
#
#            1       0.95      0.91      0.93        22
#            2       1.00      1.00      1.00         5
#            3       0.00      0.00      0.00         1
#            4       0.60      1.00      0.75         6
#            5       0.00      0.00      0.00         2
#            6       1.00      1.00      1.00         3
#            7       1.00      0.50      0.67         2
#
#     accuracy                           0.85        41
#    macro avg       0.65      0.63      0.62        41
# weighted avg       0.84      0.85      0.84        41
#
# k value =  9
#               precision    recall  f1-score   support
#
#            1       0.91      0.91      0.91        22
#            2       1.00      1.00      1.00         5
#            3       0.00      0.00      0.00         1
#            4       0.60      1.00      0.75         6
#            5       0.00      0.00      0.00         2
#            6       0.75      1.00      0.86         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.83        41
#    macro avg       0.47      0.56      0.50        41
# weighted avg       0.75      0.83      0.78        41
#
# k value =  11
#               precision    recall  f1-score   support
#
#            1       0.91      0.91      0.91        22
#            2       1.00      1.00      1.00         5
#            3       0.00      0.00      0.00         1
#            4       0.60      1.00      0.75         6
#            5       0.00      0.00      0.00         2
#            6       0.75      1.00      0.86         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.83        41
#    macro avg       0.47      0.56      0.50        41
# weighted avg       0.75      0.83      0.78        41
#
# k value =  13
#               precision    recall  f1-score   support
#
#            1       0.90      0.82      0.86        22
#            2       0.71      1.00      0.83         5
#            3       0.00      0.00      0.00         1
#            4       0.60      1.00      0.75         6
#            5       0.00      0.00      0.00         2
#            6       0.75      1.00      0.86         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.78        41
#    macro avg       0.42      0.55      0.47        41
# weighted avg       0.71      0.78      0.73        41
#
# k value =  15
#               precision    recall  f1-score   support
#
#            1       0.90      0.82      0.86        22
#            2       0.71      1.00      0.83         5
#            3       0.00      0.00      0.00         1
#            4       0.60      1.00      0.75         6
#            5       0.00      0.00      0.00         2
#            6       0.75      1.00      0.86         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.78        41
#    macro avg       0.42      0.55      0.47        41
# weighted avg       0.71      0.78      0.73        41
#
# k value =  17
#               precision    recall  f1-score   support
#
#            1       0.91      0.91      0.91        22
#            2       1.00      1.00      1.00         5
#            3       0.00      0.00      0.00         1
#            4       0.60      1.00      0.75         6
#            5       0.00      0.00      0.00         2
#            6       0.75      1.00      0.86         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.83        41
#    macro avg       0.47      0.56      0.50        41
# weighted avg       0.75      0.83      0.78        41
#
# k value =  19
#               precision    recall  f1-score   support
#
#            1       0.77      0.91      0.83        22
#            2       1.00      1.00      1.00         5
#            3       0.00      0.00      0.00         1
#            4       0.60      1.00      0.75         6
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.76        41
#    macro avg       0.34      0.42      0.37        41
# weighted avg       0.62      0.76      0.68        41
#
# k value =  21
#               precision    recall  f1-score   support
#
#            1       0.77      0.91      0.83        22
#            2       0.42      1.00      0.59         5
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.61        41
#    macro avg       0.17      0.27      0.20        41
# weighted avg       0.46      0.61      0.52        41
#
# k value =  23
#               precision    recall  f1-score   support
#
#            1       0.77      0.91      0.83        22
#            2       0.38      1.00      0.56         5
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.61        41
#    macro avg       0.16      0.27      0.20        41
# weighted avg       0.46      0.61      0.51        41
#
# k value =  25
#               precision    recall  f1-score   support
#
#            1       0.77      0.91      0.83        22
#            2       0.33      1.00      0.50         5
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.61        41
#    macro avg       0.16      0.27      0.19        41
# weighted avg       0.45      0.61      0.51        41
#
# k value =  27
#               precision    recall  f1-score   support
#
#            1       0.77      0.91      0.83        22
#            2       0.33      1.00      0.50         5
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.61        41
#    macro avg       0.16      0.27      0.19        41
# weighted avg       0.45      0.61      0.51        41
#
# k value =  29
#               precision    recall  f1-score   support
#
#            1       0.77      0.91      0.83        22
#            2       0.33      1.00      0.50         5
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.61        41
#    macro avg       0.16      0.27      0.19        41
# weighted avg       0.45      0.61      0.51        41
#
# k value =  31
#               precision    recall  f1-score   support
#
#            1       0.77      0.91      0.83        22
#            2       0.33      1.00      0.50         5
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.61        41
#    macro avg       0.16      0.27      0.19        41
# weighted avg       0.45      0.61      0.51        41
#
# k value =  33
#               precision    recall  f1-score   support
#
#            1       0.77      0.91      0.83        22
#            2       0.33      1.00      0.50         5
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.61        41
#    macro avg       0.16      0.27      0.19        41
# weighted avg       0.45      0.61      0.51        41
# k value =  35
#               precision    recall  f1-score   support
#
#            1       0.77      0.91      0.83        22
#            2       0.33      1.00      0.50         5
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.61        41
#    macro avg       0.16      0.27      0.19        41
# weighted avg       0.45      0.61      0.51        41
#
# k value =  37
#               precision    recall  f1-score   support
#
#            1       0.77      0.91      0.83        22
#            2       0.33      1.00      0.50         5
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.61        41
#    macro avg       0.16      0.27      0.19        41
# weighted avg       0.45      0.61      0.51        41
#
# k value =  39
#               precision    recall  f1-score   support
#
#            1       0.77      0.91      0.83        22
#            2       0.33      1.00      0.50         5
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         3
#            7       0.00      0.00      0.00         2
#
#     accuracy                           0.61        41
#    macro avg       0.16      0.27      0.19        41
# weighted avg       0.45      0.61      0.51        41

# %%
plt.bar(k_range,k_scores)
plt.plot(k_range,k_scores,color = "black")
plt.xlabel('value of k for kNN')
plt.ylabel('Cross-Validation Accuracy')
plt.xticks(k_range)
plt.show()

# %%
np.argmax(k_scores)
# Out:
# 0

# %%
k_range[0]
# Out:
# 1

# %%
model = KNeighborsClassifier(n_neighbors=1)
model.fit(x_train,y_train)
pred = model.predict(x_test)
accuracy_score(pred,y_test)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      1.00      1.00         5
#            3       0.00      0.00      0.00         1
#            4       0.86      1.00      0.92         6
#            5       1.00      0.50      0.67         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.95        41
#    macro avg       0.84      0.79      0.80        41
# weighted avg       0.95      0.95      0.95        41
